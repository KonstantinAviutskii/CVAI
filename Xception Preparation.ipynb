# %%
#Connecting to the GDrive
from google.colab import drive
drive.mount('/content/drive')
# %cd 'drive/MyDrive/CVAI/Task1'
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CVAI/Task1
# 'backup chest_xray'/                     TransferLearningTask.ipynb
#  chest_xray/                             Untitled0.ipynb
# 'Copy of TransferLearningTask.ipynb'     Untitled1.ipynb
# 'inception TransferLearningTask.ipynb'   vgg16pneumoniadetection.keras
#  Preparation.ipynb                      'Xception Preparation.ipynb'

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# Mount Google Drive

import os
import shutil
from tensorflow.keras.preprocessing.image import load_img, img_to_array, save_img
from tensorflow.keras.applications.xception import preprocess_input

# Paths: replace with your actual folders in Google Drive
dataset_dir = '/content/drive/MyDrive/CVAI/Task1/chest_xray/test'
processed_dir = '/content/drive/MyDrive/CVAI/Task1/chest_xray/299_test'  # Destination for processed images

# Remove existing processed folder if exists
if os.path.exists(processed_dir):
    shutil.rmtree(processed_dir)
os.makedirs(processed_dir, exist_ok=True)

# Loop through class folders
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_path):
        # Create folder in processed dataset
        processed_class_path = os.path.join(processed_dir, class_name)
        os.makedirs(processed_class_path, exist_ok=True)

        # Process each image
        for filename in os.listdir(class_path):
            if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(class_path, filename)
                try:
                    # Load, resize, convert to array
                    img = load_img(img_path, target_size=(299, 299))
                    img_array = img_to_array(img)
                    # Preprocess for VGG16
                    img_array = preprocess_input(img_array)
                    # Save the preprocessed image
                    save_path = os.path.join(processed_class_path, filename)
                    save_img(save_path, img_array)
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")

print("Dataset preprocessing complete.")
# Out:
# Dataset preprocessing complete.

# %%
import os
import shutil
from tensorflow.keras.preprocessing.image import load_img, img_to_array, save_img
from tensorflow.keras.applications.xception import preprocess_input

# Paths: replace with your actual folders in Google Drive
dataset_dir = '/content/drive/MyDrive/CVAI/Task1/chest_xray/train'
processed_dir = '/content/drive/MyDrive/CVAI/Task1/chest_xray/299_train'  # Destination for processed images

# Remove existing processed folder if exists
if os.path.exists(processed_dir):
    shutil.rmtree(processed_dir)
os.makedirs(processed_dir, exist_ok=True)

# Loop through class folders
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_path):
        # Create folder in processed dataset
        processed_class_path = os.path.join(processed_dir, class_name)
        os.makedirs(processed_class_path, exist_ok=True)

        # Process each image
        for filename in os.listdir(class_path):
            if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(class_path, filename)
                try:
                    # Load, resize, convert to array
                    img = load_img(img_path, target_size=(299, 299))
                    img_array = img_to_array(img)
                    # Preprocess for VGG16
                    img_array = preprocess_input(img_array)
                    # Save the preprocessed image
                    save_path = os.path.join(processed_class_path, filename)
                    save_img(save_path, img_array)
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")

print("Dataset preprocessing complete.")
# Out:
# Dataset preprocessing complete.

# %%
# Paths: replace with your actual folders in Google Drive
dataset_dir = '/content/drive/MyDrive/CVAI/Task1/chest_xray/val'
processed_dir = '/content/drive/MyDrive/CVAI/Task1/chest_xray/299_val'  # Destination for processed images

# Remove existing processed folder if exists
if os.path.exists(processed_dir):
    shutil.rmtree(processed_dir)
os.makedirs(processed_dir, exist_ok=True)

# Loop through class folders
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_path):
        # Create folder in processed dataset
        processed_class_path = os.path.join(processed_dir, class_name)
        os.makedirs(processed_class_path, exist_ok=True)

        # Process each image
        for filename in os.listdir(class_path):
            if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(class_path, filename)
                try:
                    # Load, resize, convert to array
                    img = load_img(img_path, target_size=(299, 299))
                    img_array = img_to_array(img)
                    # Preprocess for VGG16
                    img_array = preprocess_input(img_array)
                    # Save the preprocessed image
                    save_path = os.path.join(processed_class_path, filename)
                    save_img(save_path, img_array)
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")

print("Dataset preprocessing complete.")
# Out:
# Dataset preprocessing complete.
